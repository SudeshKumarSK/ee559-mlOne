# %% [markdown]
# # Homework : 4 Machine Learning - 1 (Supervised Methods)

# %%
# Importing required libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

from utils.oneVsRest import OneVsRest

# %%
# Importing The Bean Datasets Train and Test

# Train Dataset
train_data = pd.read_csv("./datasets/Dry_Bean_train.csv")
print("Train Data -> Dry Bean Dataset: ")
print(train_data.head())
print()
# Out:
# Train Data -> Dry Bean Dataset:
#      Area  Perimeter  MajorAxisLength  MinorAxisLength  AspectRation  \
# 0   46427    811.657       293.918029       202.246160      1.453269
# 1   35857    710.411       261.097189       175.491734      1.487803
# 2  171028   1553.271       564.123032       387.736246      1.454914
# 3   61736   1006.756       408.994308       193.596049      2.112617
# 4  102525   1238.007       478.271451       274.496251      1.742361
#
#    Eccentricity  ConvexArea  EquivDiameter    Extent  Solidity  roundness  \
# 0      0.725612       46974     243.131019  0.683796  0.988355   0.885596
# 1      0.740431       36325     213.669255  0.712891  0.987116   0.892821
# 2      0.726349      172608     466.647204  0.788962  0.990846   0.890805
# 3      0.880876       62339     280.365327  0.827416  0.990327   0.765420
# 4      0.818902      103334     361.301653  0.809201  0.992171   0.840608
#
#    Compactness  ShapeFactor1  ShapeFactor2  ShapeFactor3  ShapeFactor4  \
# 0     0.827207      0.006331      0.001828      0.684271      0.994430
# 1     0.818351      0.007282      0.002014      0.669699      0.996380
# 2     0.827208      0.003298      0.000953      0.684273      0.995559
# 3     0.685499      0.006625      0.000902      0.469909      0.992738
# 4     0.755432      0.004665      0.000937      0.570678      0.994327
#
#       Class
# 0     SEKER
# 1  DERMASON
# 2    BOMBAY
# 3     HOROZ
# 4      CALI

# %%
# Test Dataset
test_data = pd.read_csv("./datasets/Dry_Bean_test.csv")
print("Test Data -> Dry Bean Dataset: ")
print(test_data.head())
print()
# Out:
# Test Data -> Dry Bean Dataset:
#      Area  Perimeter  MajorAxisLength  MinorAxisLength  AspectRation  \
# 0   38542    724.663       273.728756       179.666585      1.523537
# 1   76070   1063.592       413.174391       235.346983      1.755597
# 2   50253    872.982       354.074847       181.355633      1.952379
# 3   44799   1005.548       362.449644       157.986158      2.294186
# 4  180028   1630.826       625.624977       371.440425      1.684321
#
#    Eccentricity  ConvexArea  EquivDiameter    Extent  Solidity  roundness  \
# 0      0.754442       38922     221.524713  0.707063  0.990237   0.922299
# 1      0.821917       76858     311.215893  0.777446  0.989747   0.845032
# 2      0.858869       50859     252.950799  0.641604  0.988085   0.828631
# 3      0.900003       46552     238.830187  0.652523  0.962343   0.556766
# 4      0.804678      183263     478.767970  0.674611  0.982348   0.850618
#
#    Compactness  ShapeFactor1  ShapeFactor2  ShapeFactor3  ShapeFactor4  \
# 0     0.809286      0.007102      0.001879      0.654943      0.997830
# 1     0.753231      0.005432      0.001078      0.567357      0.996051
# 2     0.714399      0.007046      0.001132      0.510366      0.996428
# 3     0.658933      0.008091      0.000941      0.434193      0.996120
# 4     0.765264      0.003475      0.000735      0.585628      0.986386
#
#       Class
# 0  DERMASON
# 1      CALI
# 2     HOROZ
# 3     HOROZ
# 4    BOMBAY

# %% [markdown]
# ## Creating an instance for the OneVsRest() class

# %%
ovr = OneVsRest()

# %% [markdown]
# ## 2] (a) Run the 2-class problems on the Dry Bean Dataset. Store the resulting weight vectors 𝑤𝑘 (will be used in (b)- (d) below)

# %%
n_train, X_train, T_train = ovr.generateTrainData(trainData=train_data)

X_train_std = ovr.standardizeTrainData(X_train=X_train)

X_train_augmented = ovr.augmentData(X=X_train_std, n=n_train)
print(f"Shape of Augmented X_train: {X_train_augmented.shape}")


w_vector = ovr.initializeWeights(1)
print(f"Shape of w_vector: {w_vector .shape}")
# Out:
# ---------------------------------------------------
# TRAIN DATA OF BEAN DATASET:
#   Shape of Input Data: (12249, 17)
#   Number of Data Points: 12249
#   Number of Input Features: 16
#   Number of Target Classes: 7
# ---------------------------------------------------
# Shape of Augmented X_train: (12249, 17)
# Shape of w_vector: (17, 7)

# %%
optimum_w_vector = ovr.modelTrain_SGD(X_train=X_train_augmented, n_train=n_train, T_train=T_train, w_vector = w_vector, epochs=100, labels = [0, 1, 2, 3, 4, 5, 6], learn_rate=1, printFlag=True)
# Out:
# Epoch #1 of Classifier - 1 --> Cost J(W) is: 1396.0214036815976
# Epoch #2 of Classifier - 1 --> Cost J(W) is: 989.3391389480983
# Epoch #3 of Classifier - 1 --> Cost J(W) is: 1407.5665720978477
# Epoch #4 of Classifier - 1 --> Cost J(W) is: 1390.874099178659
# Epoch #5 of Classifier - 1 --> Cost J(W) is: 1235.299974601704
# Epoch #6 of Classifier - 1 --> Cost J(W) is: 1292.7590651838261
# Epoch #7 of Classifier - 1 --> Cost J(W) is: 1108.689874118525
# Epoch #8 of Classifier - 1 --> Cost J(W) is: 1789.6440004059064
# Epoch #9 of Classifier - 1 --> Cost J(W) is: 1330.759738757808
# Epoch #10 of Classifier - 1 --> Cost J(W) is: 1217.4651836101425
# Epoch #11 of Classifier - 1 --> Cost J(W) is: 1568.601530046798
# Epoch #12 of Classifier - 1 --> Cost J(W) is: 1513.1289411776888
# Epoch #13 of Classifier - 1 --> Cost J(W) is: 2101.586748873832
# Epoch #14 of Classifier - 1 --> Cost J(W) is: 3014.6842881422485
# Epoch #15 of Classifier - 1 --> Cost J(W) is: 2842.3861961185034
# Epoch #16 of Classifier - 1 --> Cost J(W) is: 3092.940756427726
# Epoch #17 of Classifier - 1 --> Cost J(W) is: 945.7189650549275
# Epoch #18 of Classifier - 1 --> Cost J(W) is: 1338.496820310131
# Epoch #19 of Classifier - 1 --> Cost J(W) is: 1443.5940632573722
# Epoch #20 of Classifier - 1 --> Cost J(W) is: 1130.4719303866195
# Epoch #21 of Classifier - 1 --> Cost J(W) is: 1226.9243062130836
# Epoch #22 of Classifier - 1 --> Cost J(W) is: 1326.4561636119731
# Epoch #23 of Classifier - 1 --> Cost J(W) is: 3039.808560098587
# Epoch #24 of Classifier - 1 --> Cost J(W) is: 1283.8928724099937
# Epoch #25 of Classifier - 1 --> Cost J(W) is: 2417.940969465687
# Epoch #26 of Classifier - 1 --> Cost J(W) is: 974.7733351225381
# Epoch #27 of Classifier - 1 --> Cost J(W) is: 2236.008235369054
# Epoch #28 of Classifier - 1 --> Cost J(W) is: 2252.301029292292
# Epoch #29 of Classifier - 1 --> Cost J(W) is: 1169.34894673488
# Epoch #30 of Classifier - 1 --> Cost J(W) is: 1461.1446828405496
# Epoch #31 of Classifier - 1 --> Cost J(W) is: 1083.3795659751531
# Epoch #32 of Classifier - 1 --> Cost J(W) is: 1202.9361873425717
# Epoch #33 of Classifier - 1 --> Cost J(W) is: 920.9018107943875
# Epoch #34 of Classifier - 1 --> Cost J(W) is: 1360.265162962235
# Epoch #35 of Classifier - 1 --> Cost J(W) is: 1014.9909985181617
# Epoch #36 of Classifier - 1 --> Cost J(W) is: 1886.759848429481
# Epoch #37 of Classifier - 1 --> Cost J(W) is: 987.5507110648836
# Epoch #38 of Classifier - 1 --> Cost J(W) is: 1534.0644072983746
# Epoch #39 of Classifier - 1 --> Cost J(W) is: 1158.5515739061298
# Epoch #40 of Classifier - 1 --> Cost J(W) is: 1119.5031201846757
# Epoch #41 of Classifier - 1 --> Cost J(W) is: 962.132773729185
# Epoch #42 of Classifier - 1 --> Cost J(W) is: 1296.2815897905762
# Epoch #43 of Classifier - 1 --> Cost J(W) is: 922.639256412123
# Epoch #44 of Classifier - 1 --> Cost J(W) is: 1390.8929339514655
# Epoch #45 of Classifier - 1 --> Cost J(W) is: 947.2559231399188
# Epoch #46 of Classifier - 1 --> Cost J(W) is: 1223.2750829585732
# Epoch #47 of Classifier - 1 --> Cost J(W) is: 1360.5491490332129
# Epoch #48 of Classifier - 1 --> Cost J(W) is: 837.9117326541813
# Epoch #49 of Classifier - 1 --> Cost J(W) is: 1565.4768130185635
# Epoch #50 of Classifier - 1 --> Cost J(W) is: 1362.6998174602877
# Epoch #51 of Classifier - 1 --> Cost J(W) is: 1018.5510511749364
# Epoch #52 of Classifier - 1 --> Cost J(W) is: 2037.4847980073928
# Epoch #53 of Classifier - 1 --> Cost J(W) is: 1624.0425292355792
# Epoch #54 of Classifier - 1 --> Cost J(W) is: 1179.4411102962285
# Epoch #55 of Classifier - 1 --> Cost J(W) is: 1018.9373408838735
# Epoch #56 of Classifier - 1 --> Cost J(W) is: 1605.1249977625214
# Epoch #57 of Classifier - 1 --> Cost J(W) is: 1403.9574854492323
# Epoch #58 of Classifier - 1 --> Cost J(W) is: 1919.1892374402876
# Epoch #59 of Classifier - 1 --> Cost J(W) is: 2000.8669014007246
# Epoch #60 of Classifier - 1 --> Cost J(W) is: 988.3056260940187
# Epoch #61 of Classifier - 1 --> Cost J(W) is: 980.7973091570152
# Epoch #62 of Classifier - 1 --> Cost J(W) is: 2795.6845155189562
# Epoch #63 of Classifier - 1 --> Cost J(W) is: 1873.5362357631147
# Epoch #64 of Classifier - 1 --> Cost J(W) is: 3684.271817790245
# Epoch #65 of Classifier - 1 --> Cost J(W) is: 1149.9186954617837
# Epoch #66 of Classifier - 1 --> Cost J(W) is: 2378.4562669452803
# Epoch #67 of Classifier - 1 --> Cost J(W) is: 1367.464802298742
# Epoch #68 of Classifier - 1 --> Cost J(W) is: 1165.422143069852
# Epoch #69 of Classifier - 1 --> Cost J(W) is: 1329.573787654844
# Epoch #70 of Classifier - 1 --> Cost J(W) is: 1541.8648180200958
# Epoch #71 of Classifier - 1 --> Cost J(W) is: 1261.8718286037688
# Epoch #72 of Classifier - 1 --> Cost J(W) is: 1100.7664776362622
# Epoch #73 of Classifier - 1 --> Cost J(W) is: 849.475878385759
# Epoch #74 of Classifier - 1 --> Cost J(W) is: 1742.663765191649
# Epoch #75 of Classifier - 1 --> Cost J(W) is: 970.1568375952155
# Epoch #76 of Classifier - 1 --> Cost J(W) is: 921.2246028084019
# Epoch #77 of Classifier - 1 --> Cost J(W) is: 995.7645898879709
# Epoch #78 of Classifier - 1 --> Cost J(W) is: 2819.6494175482917
# Epoch #79 of Classifier - 1 --> Cost J(W) is: 2054.736491712507
# Epoch #80 of Classifier - 1 --> Cost J(W) is: 1696.5502107768687
# Epoch #81 of Classifier - 1 --> Cost J(W) is: 1168.0630239751274
# Epoch #82 of Classifier - 1 --> Cost J(W) is: 955.5623963313514
# Epoch #83 of Classifier - 1 --> Cost J(W) is: 1182.5258895273257
# Epoch #84 of Classifier - 1 --> Cost J(W) is: 2184.9288372079254
# Epoch #85 of Classifier - 1 --> Cost J(W) is: 1191.3385293932754
# Epoch #86 of Classifier - 1 --> Cost J(W) is: 1024.961031268796
# Epoch #87 of Classifier - 1 --> Cost J(W) is: 918.3924503200105
# Epoch #88 of Classifier - 1 --> Cost J(W) is: 2251.5187790450836
# Epoch #89 of Classifier - 1 --> Cost J(W) is: 3137.2429063713525
# Epoch #90 of Classifier - 1 --> Cost J(W) is: 1503.9828602337993
# Epoch #91 of Classifier - 1 --> Cost J(W) is: 1009.3233570829532
# Epoch #92 of Classifier - 1 --> Cost J(W) is: 1009.0720087466119
# Epoch #93 of Classifier - 1 --> Cost J(W) is: 1209.7318654569062
# Epoch #94 of Classifier - 1 --> Cost J(W) is: 1047.512832762218
# Epoch #95 of Classifier - 1 --> Cost J(W) is: 1514.631941249389
# Epoch #96 of Classifier - 1 --> Cost J(W) is: 954.3067041788902
# Epoch #97 of Classifier - 1 --> Cost J(W) is: 976.6391218921117
# Epoch #98 of Classifier - 1 --> Cost J(W) is: 1121.2701835003447
# Epoch #99 of Classifier - 1 --> Cost J(W) is: 1240.3594851507362
# Epoch #100 and Interation #12149of Classifier - 1 --> Cost J(W) is: 1340.6625569510584
# Epoch #100 and Interation #12179of Classifier - 1 --> Cost J(W) is: 1047.2074917326495
# Epoch #100 of Classifier - 1 --> Cost J(W) is: 1344.9283074261662
# Optimum w_vector for the 1th classifier is: [ -34.          -27.99240773  -24.09843608   19.08073165  -48.80416489
#    -7.90634629  -19.06149103  -34.29855144   -3.2787522     0.21546756
#     3.08821068   -2.59985449  -27.27486539 -106.29117657   26.69295721
#   -28.87268026    8.01077188]
# Epoch #1 of Classifier - 2 --> Cost J(W) is: 2965.8461704885035
# Epoch #2 of Classifier - 2 --> Cost J(W) is: 3666.142489077632
# Epoch #3 of Classifier - 2 --> Cost J(W) is: 2767.233388759919
# Epoch #4 of Classifier - 2 --> Cost J(W) is: 2706.43240319815
# Epoch #5 of Classifier - 2 --> Cost J(W) is: 1986.1108627241106
# Epoch #6 of Classifier - 2 --> Cost J(W) is: 3005.1771738061498
# Epoch #7 of Classifier - 2 --> Cost J(W) is: 2615.6010563533755
# Epoch #8 of Classifier - 2 --> Cost J(W) is: 4398.663763486506
# Epoch #9 of Classifier - 2 --> Cost J(W) is: 2654.9219170819006
# Epoch #10 of Classifier - 2 --> Cost J(W) is: 2478.4048355560462
# Epoch #11 of Classifier - 2 --> Cost J(W) is: 2956.5227831559064
# Epoch #12 of Classifier - 2 --> Cost J(W) is: 2178.705518720325
# Epoch #13 of Classifier - 2 --> Cost J(W) is: 1954.0069044690852
# Epoch #14 of Classifier - 2 --> Cost J(W) is: 3517.4430605077023
# Epoch #15 of Classifier - 2 --> Cost J(W) is: 20064.04059690064
# Epoch #16 of Classifier - 2 --> Cost J(W) is: 2367.349198226649
# Epoch #17 of Classifier - 2 --> Cost J(W) is: 2550.294468851435
# Epoch #18 of Classifier - 2 --> Cost J(W) is: 2057.259996127115
# Epoch #19 of Classifier - 2 --> Cost J(W) is: 2076.4937950425515
# Epoch #20 of Classifier - 2 --> Cost J(W) is: 3612.545933680545
# Epoch #21 of Classifier - 2 --> Cost J(W) is: 2427.7062676612463
# Epoch #22 of Classifier - 2 --> Cost J(W) is: 2492.5934871810373
# Epoch #23 of Classifier - 2 --> Cost J(W) is: 1723.1758455255485
# Epoch #24 of Classifier - 2 --> Cost J(W) is: 2337.70663726892
# Epoch #25 of Classifier - 2 --> Cost J(W) is: 2809.1040936997833
# Epoch #26 of Classifier - 2 --> Cost J(W) is: 3464.594197775233
# Epoch #27 of Classifier - 2 --> Cost J(W) is: 2064.122581061221
# Epoch #28 of Classifier - 2 --> Cost J(W) is: 1760.9689213940164
# Epoch #29 of Classifier - 2 --> Cost J(W) is: 2099.236643788617
# Epoch #30 of Classifier - 2 --> Cost J(W) is: 2689.749499066519
# Epoch #31 of Classifier - 2 --> Cost J(W) is: 1737.361413164525
# Epoch #32 of Classifier - 2 --> Cost J(W) is: 2185.0580942823963
# Epoch #33 of Classifier - 2 --> Cost J(W) is: 3844.4102412904986
# Epoch #34 of Classifier - 2 --> Cost J(W) is: 1881.8039866533204
# Epoch #35 of Classifier - 2 --> Cost J(W) is: 3157.163579339941
# Epoch #36 of Classifier - 2 --> Cost J(W) is: 2351.692832887741
# Epoch #37 of Classifier - 2 --> Cost J(W) is: 2706.248220840612
# Epoch #38 of Classifier - 2 --> Cost J(W) is: 2707.498793784807
# Epoch #39 of Classifier - 2 --> Cost J(W) is: 2718.4496384272916
# Epoch #40 of Classifier - 2 --> Cost J(W) is: 2099.4664416112187
# Epoch #41 of Classifier - 2 --> Cost J(W) is: 1724.0558604718342
# Epoch #42 of Classifier - 2 --> Cost J(W) is: 1747.7034367356482
# Epoch #43 of Classifier - 2 --> Cost J(W) is: 3411.195989888245
# Epoch #44 of Classifier - 2 --> Cost J(W) is: 2173.8260238463013
# Epoch #45 of Classifier - 2 --> Cost J(W) is: 1875.1412480142749
# Epoch #46 of Classifier - 2 --> Cost J(W) is: 2523.6653538318424
# Epoch #47 of Classifier - 2 --> Cost J(W) is: 1910.5807710949848
# Epoch #48 of Classifier - 2 --> Cost J(W) is: 2272.6157453171068
# Epoch #49 of Classifier - 2 --> Cost J(W) is: 2273.317578945908
# Epoch #50 of Classifier - 2 --> Cost J(W) is: 1888.3666064116414
# Epoch #51 of Classifier - 2 --> Cost J(W) is: 5010.480605568891
# Epoch #52 of Classifier - 2 --> Cost J(W) is: 2373.4346146410267
# Epoch #53 of Classifier - 2 --> Cost J(W) is: 2906.701510344526
# Epoch #54 of Classifier - 2 --> Cost J(W) is: 2244.954650248936
# Epoch #55 of Classifier - 2 --> Cost J(W) is: 3074.528357989411
# Epoch #56 of Classifier - 2 --> Cost J(W) is: 2704.3223609838515
# Epoch #57 of Classifier - 2 --> Cost J(W) is: 1981.44445726606
# Epoch #58 of Classifier - 2 --> Cost J(W) is: 3120.4097562216202
# Epoch #59 of Classifier - 2 --> Cost J(W) is: 2783.156648732289
# Epoch #60 of Classifier - 2 --> Cost J(W) is: 5490.961459831732
# Epoch #61 of Classifier - 2 --> Cost J(W) is: 2096.4553577153056
# Epoch #62 of Classifier - 2 --> Cost J(W) is: 2774.893724928278
# Epoch #63 of Classifier - 2 --> Cost J(W) is: 3653.187277045199
# Epoch #64 of Classifier - 2 --> Cost J(W) is: 2093.7795374900943
# Epoch #65 of Classifier - 2 --> Cost J(W) is: 2560.423493940703
# Epoch #66 of Classifier - 2 --> Cost J(W) is: 14125.785983222195
# Epoch #67 of Classifier - 2 --> Cost J(W) is: 1814.175279211232
# Epoch #68 of Classifier - 2 --> Cost J(W) is: 3916.787811395947
# Epoch #69 of Classifier - 2 --> Cost J(W) is: 3236.3661326063093
# Epoch #70 of Classifier - 2 --> Cost J(W) is: 2124.6244446101955
# Epoch #71 of Classifier - 2 --> Cost J(W) is: 2185.8874859952994
# Epoch #72 of Classifier - 2 --> Cost J(W) is: 2192.1551554854564
# Epoch #73 of Classifier - 2 --> Cost J(W) is: 1992.3539260887635
# Epoch #74 of Classifier - 2 --> Cost J(W) is: 3622.363265052574
# Epoch #75 of Classifier - 2 --> Cost J(W) is: 2434.5760413657054
# Epoch #76 of Classifier - 2 --> Cost J(W) is: 5627.174580028235
# Epoch #77 of Classifier - 2 --> Cost J(W) is: 2642.897406288144
# Epoch #78 of Classifier - 2 --> Cost J(W) is: 2990.0383013972423
# Epoch #79 of Classifier - 2 --> Cost J(W) is: 1922.576341067809
# Epoch #80 of Classifier - 2 --> Cost J(W) is: 2801.4441140033546
# Epoch #81 of Classifier - 2 --> Cost J(W) is: 1726.890334675367
# Epoch #82 of Classifier - 2 --> Cost J(W) is: 3282.8254200956117
# Epoch #83 of Classifier - 2 --> Cost J(W) is: 1792.9431147645541
# Epoch #84 of Classifier - 2 --> Cost J(W) is: 2986.728525655757
# Epoch #85 of Classifier - 2 --> Cost J(W) is: 2824.2060693670987
# Epoch #86 of Classifier - 2 --> Cost J(W) is: 2283.103414890359
# Epoch #87 of Classifier - 2 --> Cost J(W) is: 7801.428738333307
# Epoch #88 of Classifier - 2 --> Cost J(W) is: 3937.80928392691
# Epoch #89 of Classifier - 2 --> Cost J(W) is: 4749.141872595414
# Epoch #90 of Classifier - 2 --> Cost J(W) is: 3374.266325272436
# Epoch #91 of Classifier - 2 --> Cost J(W) is: 2014.5741601220584
# Epoch #92 of Classifier - 2 --> Cost J(W) is: 3079.1459788177326
# Epoch #93 of Classifier - 2 --> Cost J(W) is: 1758.149363285491
# Epoch #94 of Classifier - 2 --> Cost J(W) is: 2483.4171266635713
# Epoch #95 of Classifier - 2 --> Cost J(W) is: 3259.4094684733054
# Epoch #96 of Classifier - 2 --> Cost J(W) is: 2966.615976583376
# Epoch #97 of Classifier - 2 --> Cost J(W) is: 2051.617283977605
# Epoch #98 of Classifier - 2 --> Cost J(W) is: 4286.728998467517
# Epoch #99 of Classifier - 2 --> Cost J(W) is: 3497.4602807311194
# Epoch #100 and Interation #12149of Classifier - 2 --> Cost J(W) is: 3132.80032519458
# Epoch #100 and Interation #12160of Classifier - 2 --> Cost J(W) is: 2064.0666732882764
# Epoch #100 and Interation #12169of Classifier - 2 --> Cost J(W) is: 1636.1446156792945
# Epoch #100 of Classifier - 2 --> Cost J(W) is: 1702.797467631337
# Optimum w_vector for the 2th classifier is: [-14.          -4.38820838  18.79389765  -4.88164685  11.62756891
#    1.17411158  56.47803507 -11.99126963   4.74927891  -1.37702076
#   -0.38049233   5.42016218  23.0511818   11.42083279  29.94082933
#   12.36369074   0.22959397]
# Epoch #1 of Classifier - 3 --> Cost J(W) is: 4.058123976323262
# Epoch #2 of Classifier - 3 --> Cost J(W) is: 9.041801748082136
# Epoch #3 of Classifier - 3 --> Cost J(W) is: 40.557502216232024
# Epoch #4 of Classifier - 3 --> Cost J(W) is: 0.6330062659592954
# Epoch #5 of Classifier - 3 --> Cost J(W) is: 0
# Epoch #6 of Classifier - 3 --> Cost J(W) is: 0
# Epoch #7 of Classifier - 3 --> Cost J(W) is: 0
# Epoch #8 of Classifier - 3 --> Cost J(W) is: 0
# Epoch #9 of Classifier - 3 --> Cost J(W) is: 0
# Epoch #10 of Classifier - 3 --> Cost J(W) is: 0
# Epoch #11 of Classifier - 3 --> Cost J(W) is: 0
# Epoch #12 of Classifier - 3 --> Cost J(W) is: 0
# Epoch #13 of Classifier - 3 --> Cost J(W) is: 0
# Epoch #14 of Classifier - 3 --> Cost J(W) is: 0
# Epoch #15 of Classifier - 3 --> Cost J(W) is: 0
# Epoch #16 of Classifier - 3 --> Cost J(W) is: 0
# Epoch #17 of Classifier - 3 --> Cost J(W) is: 0
# Epoch #18 of Classifier - 3 --> Cost J(W) is: 0
# Epoch #19 of Classifier - 3 --> Cost J(W) is: 0
# Epoch #20 of Classifier - 3 --> Cost J(W) is: 0
# Epoch #21 of Classifier - 3 --> Cost J(W) is: 0
# Epoch #22 of Classifier - 3 --> Cost J(W) is: 0
# Epoch #23 of Classifier - 3 --> Cost J(W) is: 0
# Epoch #24 of Classifier - 3 --> Cost J(W) is: 0
# Epoch #25 of Classifier - 3 --> Cost J(W) is: 0
# Epoch #26 of Classifier - 3 --> Cost J(W) is: 0
# Epoch #27 of Classifier - 3 --> Cost J(W) is: 0
# Epoch #28 of Classifier - 3 --> Cost J(W) is: 0
# Epoch #29 of Classifier - 3 --> Cost J(W) is: 0
# Epoch #30 of Classifier - 3 --> Cost J(W) is: 0
# Epoch #31 of Classifier - 3 --> Cost J(W) is: 0
# Epoch #32 of Classifier - 3 --> Cost J(W) is: 0
# Epoch #33 of Classifier - 3 --> Cost J(W) is: 0
# Epoch #34 of Classifier - 3 --> Cost J(W) is: 0
# Epoch #35 of Classifier - 3 --> Cost J(W) is: 0
# Epoch #36 of Classifier - 3 --> Cost J(W) is: 0
# Epoch #37 of Classifier - 3 --> Cost J(W) is: 0
# Epoch #38 of Classifier - 3 --> Cost J(W) is: 0
# Epoch #39 of Classifier - 3 --> Cost J(W) is: 0
# Epoch #40 of Classifier - 3 --> Cost J(W) is: 0
# Epoch #41 of Classifier - 3 --> Cost J(W) is: 0
# Epoch #42 of Classifier - 3 --> Cost J(W) is: 0
# Epoch #43 of Classifier - 3 --> Cost J(W) is: 0
# Epoch #44 of Classifier - 3 --> Cost J(W) is: 0
# Epoch #45 of Classifier - 3 --> Cost J(W) is: 0
# Epoch #46 of Classifier - 3 --> Cost J(W) is: 0
# Epoch #47 of Classifier - 3 --> Cost J(W) is: 0
# Epoch #48 of Classifier - 3 --> Cost J(W) is: 0
# Epoch #49 of Classifier - 3 --> Cost J(W) is: 0
# Epoch #50 of Classifier - 3 --> Cost J(W) is: 0
# Epoch #51 of Classifier - 3 --> Cost J(W) is: 0
# Epoch #52 of Classifier - 3 --> Cost J(W) is: 0
# Epoch #53 of Classifier - 3 --> Cost J(W) is: 0
# Epoch #54 of Classifier - 3 --> Cost J(W) is: 0
# Epoch #55 of Classifier - 3 --> Cost J(W) is: 0
# Epoch #56 of Classifier - 3 --> Cost J(W) is: 0
# Epoch #57 of Classifier - 3 --> Cost J(W) is: 0
# Epoch #58 of Classifier - 3 --> Cost J(W) is: 0
# Epoch #59 of Classifier - 3 --> Cost J(W) is: 0
# Epoch #60 of Classifier - 3 --> Cost J(W) is: 0
# Epoch #61 of Classifier - 3 --> Cost J(W) is: 0
# Epoch #62 of Classifier - 3 --> Cost J(W) is: 0
# Epoch #63 of Classifier - 3 --> Cost J(W) is: 0
# Epoch #64 of Classifier - 3 --> Cost J(W) is: 0
# Epoch #65 of Classifier - 3 --> Cost J(W) is: 0
# Epoch #66 of Classifier - 3 --> Cost J(W) is: 0
# Epoch #67 of Classifier - 3 --> Cost J(W) is: 0
# Epoch #68 of Classifier - 3 --> Cost J(W) is: 0
# Epoch #69 of Classifier - 3 --> Cost J(W) is: 0
# Epoch #70 of Classifier - 3 --> Cost J(W) is: 0
# Epoch #71 of Classifier - 3 --> Cost J(W) is: 0
# Epoch #72 of Classifier - 3 --> Cost J(W) is: 0
# Epoch #73 of Classifier - 3 --> Cost J(W) is: 0
# Epoch #74 of Classifier - 3 --> Cost J(W) is: 0
# Epoch #75 of Classifier - 3 --> Cost J(W) is: 0
# Epoch #76 of Classifier - 3 --> Cost J(W) is: 0
# Epoch #77 of Classifier - 3 --> Cost J(W) is: 0
# Epoch #78 of Classifier - 3 --> Cost J(W) is: 0
# Epoch #79 of Classifier - 3 --> Cost J(W) is: 0
# Epoch #80 of Classifier - 3 --> Cost J(W) is: 0
# Epoch #81 of Classifier - 3 --> Cost J(W) is: 0
# Epoch #82 of Classifier - 3 --> Cost J(W) is: 0
# Epoch #83 of Classifier - 3 --> Cost J(W) is: 0
# Epoch #84 of Classifier - 3 --> Cost J(W) is: 0
# Epoch #85 of Classifier - 3 --> Cost J(W) is: 0
# Epoch #86 of Classifier - 3 --> Cost J(W) is: 0
# Epoch #87 of Classifier - 3 --> Cost J(W) is: 0
# Epoch #88 of Classifier - 3 --> Cost J(W) is: 0
# Epoch #89 of Classifier - 3 --> Cost J(W) is: 0
# Epoch #90 of Classifier - 3 --> Cost J(W) is: 0
# Epoch #91 of Classifier - 3 --> Cost J(W) is: 0
# Epoch #92 of Classifier - 3 --> Cost J(W) is: 0
# Epoch #93 of Classifier - 3 --> Cost J(W) is: 0
# Epoch #94 of Classifier - 3 --> Cost J(W) is: 0
# Epoch #95 of Classifier - 3 --> Cost J(W) is: 0
# Epoch #96 of Classifier - 3 --> Cost J(W) is: 0
# Epoch #97 of Classifier - 3 --> Cost J(W) is: 0
# Epoch #98 of Classifier - 3 --> Cost J(W) is: 0
# Epoch #99 of Classifier - 3 --> Cost J(W) is: 0
# Epoch #100 and Interation #12149of Classifier - 3 --> Cost J(W) is: 0
# Epoch #100 of Classifier - 3 --> Cost J(W) is: 0
# Optimum w_vector for the 3th classifier is: [-36.          12.96612121   1.08004819   1.18188489   4.89732736
#   -1.63210506   1.75214665  13.02115737   3.00970102  -1.65491951
#    1.27620146  10.97901917   3.08587967  13.63609087   5.92383311
#    2.71675975   4.67495161]
# Epoch #1 of Classifier - 4 --> Cost J(W) is: 1462.4152568669465
# Epoch #2 of Classifier - 4 --> Cost J(W) is: 1667.3536392917817
# Epoch #3 of Classifier - 4 --> Cost J(W) is: 2092.7942402705676
# Epoch #4 of Classifier - 4 --> Cost J(W) is: 1580.2363547548107
# Epoch #5 of Classifier - 4 --> Cost J(W) is: 1525.6133232003879
# Epoch #6 of Classifier - 4 --> Cost J(W) is: 1951.4218919723064
# Epoch #7 of Classifier - 4 --> Cost J(W) is: 1255.4755471700034
# Epoch #8 of Classifier - 4 --> Cost J(W) is: 1652.5395443977836
# Epoch #9 of Classifier - 4 --> Cost J(W) is: 1772.8635320397434
# Epoch #10 of Classifier - 4 --> Cost J(W) is: 2329.4847939269116
# Epoch #11 of Classifier - 4 --> Cost J(W) is: 1595.5071362097651
# Epoch #12 of Classifier - 4 --> Cost J(W) is: 1960.182696560964
# Epoch #13 of Classifier - 4 --> Cost J(W) is: 12295.433034095031
# Epoch #14 of Classifier - 4 --> Cost J(W) is: 1968.8267366247705
# Epoch #15 of Classifier - 4 --> Cost J(W) is: 1639.3057252516746
# Epoch #16 of Classifier - 4 --> Cost J(W) is: 1278.3173535247067
# Epoch #17 of Classifier - 4 --> Cost J(W) is: 2336.700517296267
# Epoch #18 of Classifier - 4 --> Cost J(W) is: 2890.3225123817633
# Epoch #19 of Classifier - 4 --> Cost J(W) is: 1868.7419830799586
# Epoch #20 of Classifier - 4 --> Cost J(W) is: 1660.8471335890245
# Epoch #21 of Classifier - 4 --> Cost J(W) is: 1739.3537954768958
# Epoch #22 of Classifier - 4 --> Cost J(W) is: 3463.4250473452457
# Epoch #23 of Classifier - 4 --> Cost J(W) is: 2584.925235518121
# Epoch #24 of Classifier - 4 --> Cost J(W) is: 2358.4242562159343
# Epoch #25 of Classifier - 4 --> Cost J(W) is: 3567.9733773655926
# Epoch #26 of Classifier - 4 --> Cost J(W) is: 2873.544651102718
# Epoch #27 of Classifier - 4 --> Cost J(W) is: 1791.6888166138945
# Epoch #28 of Classifier - 4 --> Cost J(W) is: 1877.2634310518151
# Epoch #29 of Classifier - 4 --> Cost J(W) is: 1774.0326581153986
# Epoch #30 of Classifier - 4 --> Cost J(W) is: 3400.5696210362485
# Epoch #31 of Classifier - 4 --> Cost J(W) is: 1494.6012602805804
# Epoch #32 of Classifier - 4 --> Cost J(W) is: 1793.4690373050832
# Epoch #33 of Classifier - 4 --> Cost J(W) is: 1457.8006378833688
# Epoch #34 of Classifier - 4 --> Cost J(W) is: 1753.1686759443382
# Epoch #35 of Classifier - 4 --> Cost J(W) is: 1393.1518443868986
# Epoch #36 of Classifier - 4 --> Cost J(W) is: 5984.4913887904895
# Epoch #37 of Classifier - 4 --> Cost J(W) is: 1416.6092057645083
# Epoch #38 of Classifier - 4 --> Cost J(W) is: 2041.0470285971114
# Epoch #39 of Classifier - 4 --> Cost J(W) is: 2103.330847952771
# Epoch #40 of Classifier - 4 --> Cost J(W) is: 4569.925785199295
# Epoch #41 of Classifier - 4 --> Cost J(W) is: 2333.459223641775
# Epoch #42 of Classifier - 4 --> Cost J(W) is: 1768.2761312898692
# Epoch #43 of Classifier - 4 --> Cost J(W) is: 3162.0645215611785
# Epoch #44 of Classifier - 4 --> Cost J(W) is: 2661.8636332012875
# Epoch #45 of Classifier - 4 --> Cost J(W) is: 1544.83066893727
# Epoch #46 of Classifier - 4 --> Cost J(W) is: 1286.25705199654
# Epoch #47 of Classifier - 4 --> Cost J(W) is: 1996.5513265773982
# Epoch #48 of Classifier - 4 --> Cost J(W) is: 1428.2100277729933
# Epoch #49 of Classifier - 4 --> Cost J(W) is: 2160.8149249030453
# Epoch #50 of Classifier - 4 --> Cost J(W) is: 1384.443598906286
# Epoch #51 of Classifier - 4 --> Cost J(W) is: 6107.691561590014
# Epoch #52 of Classifier - 4 --> Cost J(W) is: 1796.8946972339131
# Epoch #53 of Classifier - 4 --> Cost J(W) is: 2591.464272211789
# Epoch #54 of Classifier - 4 --> Cost J(W) is: 1417.5630308135505
# Epoch #55 of Classifier - 4 --> Cost J(W) is: 2062.240479574081
# Epoch #56 of Classifier - 4 --> Cost J(W) is: 3069.028173075963
# Epoch #57 of Classifier - 4 --> Cost J(W) is: 1507.455867846638
# Epoch #58 of Classifier - 4 --> Cost J(W) is: 2074.281785679501
# Epoch #59 of Classifier - 4 --> Cost J(W) is: 3447.889054958905
# Epoch #60 of Classifier - 4 --> Cost J(W) is: 2039.3200078225193
# Epoch #61 of Classifier - 4 --> Cost J(W) is: 1477.9476087775422
# Epoch #62 of Classifier - 4 --> Cost J(W) is: 1740.7956480738112
# Epoch #63 of Classifier - 4 --> Cost J(W) is: 4599.350530289548
# Epoch #64 of Classifier - 4 --> Cost J(W) is: 3302.8100818201397
# Epoch #65 of Classifier - 4 --> Cost J(W) is: 2099.798910123785
# Epoch #66 of Classifier - 4 --> Cost J(W) is: 6880.968502409675
# Epoch #67 of Classifier - 4 --> Cost J(W) is: 2473.8865388364306
# Epoch #68 of Classifier - 4 --> Cost J(W) is: 1654.906071228449
# Epoch #69 of Classifier - 4 --> Cost J(W) is: 1362.8799169864167
# Epoch #70 of Classifier - 4 --> Cost J(W) is: 1589.5425329422653
# Epoch #71 of Classifier - 4 --> Cost J(W) is: 1771.4585024812188
# Epoch #72 of Classifier - 4 --> Cost J(W) is: 2117.96426831749
# Epoch #73 of Classifier - 4 --> Cost J(W) is: 2287.9728740560595
# Epoch #74 of Classifier - 4 --> Cost J(W) is: 1666.9194047878912
# Epoch #75 of Classifier - 4 --> Cost J(W) is: 2194.6476584275815
# Epoch #76 of Classifier - 4 --> Cost J(W) is: 3415.3519396719876
# Epoch #77 of Classifier - 4 --> Cost J(W) is: 1815.6204631790488
# Epoch #78 of Classifier - 4 --> Cost J(W) is: 2241.611900491718
# Epoch #79 of Classifier - 4 --> Cost J(W) is: 1505.5384738482223
# Epoch #80 of Classifier - 4 --> Cost J(W) is: 1628.6106530360094
# Epoch #81 of Classifier - 4 --> Cost J(W) is: 2058.542713191996
# Epoch #82 of Classifier - 4 --> Cost J(W) is: 1822.6192431256584
# Epoch #83 of Classifier - 4 --> Cost J(W) is: 1720.6983724195609
# Epoch #84 of Classifier - 4 --> Cost J(W) is: 4577.345505730059
# Epoch #85 of Classifier - 4 --> Cost J(W) is: 3704.7417127854646
# Epoch #86 of Classifier - 4 --> Cost J(W) is: 2931.3498309394345
# Epoch #87 of Classifier - 4 --> Cost J(W) is: 1554.409560200925
# Epoch #88 of Classifier - 4 --> Cost J(W) is: 1581.9238491124454
# Epoch #89 of Classifier - 4 --> Cost J(W) is: 2571.2002116842345
# Epoch #90 of Classifier - 4 --> Cost J(W) is: 1576.970600869073
# Epoch #91 of Classifier - 4 --> Cost J(W) is: 2222.308486410325
# Epoch #92 of Classifier - 4 --> Cost J(W) is: 2934.711329879435
# Epoch #93 of Classifier - 4 --> Cost J(W) is: 2364.6179450704926
# Epoch #94 of Classifier - 4 --> Cost J(W) is: 2024.544068463555
# Epoch #95 of Classifier - 4 --> Cost J(W) is: 1583.5799485802454
# Epoch #96 of Classifier - 4 --> Cost J(W) is: 1646.04145216695
# Epoch #97 of Classifier - 4 --> Cost J(W) is: 2309.353762337346
# Epoch #98 of Classifier - 4 --> Cost J(W) is: 2106.479120288744
# Epoch #99 of Classifier - 4 --> Cost J(W) is: 1599.2618255730877
# Epoch #100 and Interation #12149of Classifier - 4 --> Cost J(W) is: 1624.1237135841923
# Epoch #100 of Classifier - 4 --> Cost J(W) is: 1947.4473422989563
# Optimum w_vector for the 4th classifier is: [-37.         -45.49657341  10.93963547   3.51931846 -10.416396
#   68.55823727  10.04299956 -47.48821823 -11.60352031   2.09054019
#    0.09565524  -0.68048531  11.56455923 -49.19602799   2.31285257
#   27.21059452  -8.53624716]
# Epoch #1 of Classifier - 5 --> Cost J(W) is: 4951.334696862358
# Epoch #2 of Classifier - 5 --> Cost J(W) is: 2952.4046186025325
# Epoch #3 of Classifier - 5 --> Cost J(W) is: 1706.5644449233487
# Epoch #4 of Classifier - 5 --> Cost J(W) is: 2480.1437979646735
# Epoch #5 of Classifier - 5 --> Cost J(W) is: 2257.2979915562137
# Epoch #6 of Classifier - 5 --> Cost J(W) is: 1889.369552124776
# Epoch #7 of Classifier - 5 --> Cost J(W) is: 2390.131133454574
# Epoch #8 of Classifier - 5 --> Cost J(W) is: 2847.7823906815825
# Epoch #9 of Classifier - 5 --> Cost J(W) is: 2725.170771817768
# Epoch #10 of Classifier - 5 --> Cost J(W) is: 2278.3389695342607
# Epoch #11 of Classifier - 5 --> Cost J(W) is: 2479.3018130702694
# Epoch #12 of Classifier - 5 --> Cost J(W) is: 2186.3011042035496
# Epoch #13 of Classifier - 5 --> Cost J(W) is: 3040.549815713296
# Epoch #14 of Classifier - 5 --> Cost J(W) is: 1919.732009126372
# Epoch #15 of Classifier - 5 --> Cost J(W) is: 1760.5347042512433
# Epoch #16 of Classifier - 5 --> Cost J(W) is: 2191.1950084832033
# Epoch #17 of Classifier - 5 --> Cost J(W) is: 2102.1833547603
# Epoch #18 of Classifier - 5 --> Cost J(W) is: 1809.335271494195
# Epoch #19 of Classifier - 5 --> Cost J(W) is: 3295.2662132037135
# Epoch #20 of Classifier - 5 --> Cost J(W) is: 7676.763471651534
# Epoch #21 of Classifier - 5 --> Cost J(W) is: 2189.8265526439695
# Epoch #22 of Classifier - 5 --> Cost J(W) is: 1575.7071567924104
# Epoch #23 of Classifier - 5 --> Cost J(W) is: 3258.834239522518
# Epoch #24 of Classifier - 5 --> Cost J(W) is: 3617.275497708632
# Epoch #25 of Classifier - 5 --> Cost J(W) is: 7418.717770395782
# Epoch #26 of Classifier - 5 --> Cost J(W) is: 2212.078030428829
# Epoch #27 of Classifier - 5 --> Cost J(W) is: 2789.8584186798926
# Epoch #28 of Classifier - 5 --> Cost J(W) is: 2686.599403229073
# Epoch #29 of Classifier - 5 --> Cost J(W) is: 3613.803783056036
# Epoch #30 of Classifier - 5 --> Cost J(W) is: 1688.9617875992944
# Epoch #31 of Classifier - 5 --> Cost J(W) is: 6874.014540513062
# Epoch #32 of Classifier - 5 --> Cost J(W) is: 2384.5133870168756
# Epoch #33 of Classifier - 5 --> Cost J(W) is: 2264.086920496801
# Epoch #34 of Classifier - 5 --> Cost J(W) is: 2592.2773136617325
# Epoch #35 of Classifier - 5 --> Cost J(W) is: 1885.3596062613633
# Epoch #36 of Classifier - 5 --> Cost J(W) is: 2748.4523739074994
# Epoch #37 of Classifier - 5 --> Cost J(W) is: 3056.982563823555
# Epoch #38 of Classifier - 5 --> Cost J(W) is: 2825.120487695076
# Epoch #39 of Classifier - 5 --> Cost J(W) is: 2293.6444078296863
# Epoch #40 of Classifier - 5 --> Cost J(W) is: 2910.6383699255175
# Epoch #41 of Classifier - 5 --> Cost J(W) is: 2377.877279781165
# Epoch #42 of Classifier - 5 --> Cost J(W) is: 2665.7090009420417
# Epoch #43 of Classifier - 5 --> Cost J(W) is: 1789.4657029475516
# Epoch #44 of Classifier - 5 --> Cost J(W) is: 3979.851966767221
# Epoch #45 of Classifier - 5 --> Cost J(W) is: 2361.167721023469
# Epoch #46 of Classifier - 5 --> Cost J(W) is: 1848.391221464104
# Epoch #47 of Classifier - 5 --> Cost J(W) is: 3161.507992415198
# Epoch #48 of Classifier - 5 --> Cost J(W) is: 15176.976637581187
# Epoch #49 of Classifier - 5 --> Cost J(W) is: 3158.3449520345503
# Epoch #50 of Classifier - 5 --> Cost J(W) is: 2278.77346677628
# Epoch #51 of Classifier - 5 --> Cost J(W) is: 2342.621616924984
# Epoch #52 of Classifier - 5 --> Cost J(W) is: 1814.8927437097927
# Epoch #53 of Classifier - 5 --> Cost J(W) is: 1685.1066845661135
# Epoch #54 of Classifier - 5 --> Cost J(W) is: 1786.2179674482245
# Epoch #55 of Classifier - 5 --> Cost J(W) is: 2286.5484055213465
# Epoch #56 of Classifier - 5 --> Cost J(W) is: 2365.121185019254
# Epoch #57 of Classifier - 5 --> Cost J(W) is: 4901.649255745337
# Epoch #58 of Classifier - 5 --> Cost J(W) is: 2686.0475576578283
# Epoch #59 of Classifier - 5 --> Cost J(W) is: 1804.9150151461017
# Epoch #60 of Classifier - 5 --> Cost J(W) is: 1819.8203767018729
# Epoch #61 of Classifier - 5 --> Cost J(W) is: 1784.0090887324905
# Epoch #62 of Classifier - 5 --> Cost J(W) is: 2184.6223818218273
# Epoch #63 of Classifier - 5 --> Cost J(W) is: 1835.795801122499
# Epoch #64 of Classifier - 5 --> Cost J(W) is: 2993.5014709017587
# Epoch #65 of Classifier - 5 --> Cost J(W) is: 4402.970383978112
# Epoch #66 of Classifier - 5 --> Cost J(W) is: 2042.2201303801146
# Epoch #67 of Classifier - 5 --> Cost J(W) is: 3707.1072489965322
# Epoch #68 of Classifier - 5 --> Cost J(W) is: 2160.7959479663054
# Epoch #69 of Classifier - 5 --> Cost J(W) is: 2191.9340637093487
# Epoch #70 of Classifier - 5 --> Cost J(W) is: 1516.5480772355577
# Epoch #71 of Classifier - 5 --> Cost J(W) is: 2418.5182994486017
# Epoch #72 of Classifier - 5 --> Cost J(W) is: 3594.467023042472
# Epoch #73 of Classifier - 5 --> Cost J(W) is: 2505.7902710279536
# Epoch #74 of Classifier - 5 --> Cost J(W) is: 1612.0653940700304
# Epoch #75 of Classifier - 5 --> Cost J(W) is: 4179.505136649274
# Epoch #76 of Classifier - 5 --> Cost J(W) is: 3940.2205590053795
# Epoch #77 of Classifier - 5 --> Cost J(W) is: 4840.727373946629
# Epoch #78 of Classifier - 5 --> Cost J(W) is: 1887.4091197565858
# Epoch #79 of Classifier - 5 --> Cost J(W) is: 1881.0594060484564
# Epoch #80 of Classifier - 5 --> Cost J(W) is: 5174.445990019601
# Epoch #81 of Classifier - 5 --> Cost J(W) is: 4040.2276784764963
# Epoch #82 of Classifier - 5 --> Cost J(W) is: 1850.2035442446584
# Epoch #83 of Classifier - 5 --> Cost J(W) is: 2315.710308256621
# Epoch #84 of Classifier - 5 --> Cost J(W) is: 1725.8082161201085
# Epoch #85 of Classifier - 5 --> Cost J(W) is: 3011.173842959083
# Epoch #86 of Classifier - 5 --> Cost J(W) is: 1883.4107868185654
# Epoch #87 of Classifier - 5 --> Cost J(W) is: 1867.718802800349
# Epoch #88 of Classifier - 5 --> Cost J(W) is: 2857.573920938667
# Epoch #89 of Classifier - 5 --> Cost J(W) is: 1964.1134450841057
# Epoch #90 of Classifier - 5 --> Cost J(W) is: 2062.83874542319
# Epoch #91 of Classifier - 5 --> Cost J(W) is: 2787.3416364977493
# Epoch #92 of Classifier - 5 --> Cost J(W) is: 2200.075062602265
# Epoch #93 of Classifier - 5 --> Cost J(W) is: 3127.275427953894
# Epoch #94 of Classifier - 5 --> Cost J(W) is: 1893.0887688689502
# Epoch #95 of Classifier - 5 --> Cost J(W) is: 1967.6867287772866
# Epoch #96 of Classifier - 5 --> Cost J(W) is: 1605.509072894884
# Epoch #97 of Classifier - 5 --> Cost J(W) is: 2512.9189312594353
# Epoch #98 of Classifier - 5 --> Cost J(W) is: 2241.0247192222373
# Epoch #99 of Classifier - 5 --> Cost J(W) is: 3437.099590174748
# Epoch #100 and Interation #12149of Classifier - 5 --> Cost J(W) is: 1901.3494001484373
# Epoch #100 and Interation #12206of Classifier - 5 --> Cost J(W) is: 1839.0368242657737
# Epoch #100 and Interation #12219of Classifier - 5 --> Cost J(W) is: 1659.8268256866797
# Epoch #100 of Classifier - 5 --> Cost J(W) is: 1659.8268256866797
# Optimum w_vector for the 5th classifier is: [-5.10000000e+01 -3.15159666e+01 -3.19710668e+01  6.98108426e+01
#  -7.70054840e+01 -6.46131055e+01  3.08138150e+01 -9.12397136e+00
#  -5.07101337e+00  6.51637981e-01 -3.52611826e-02  1.43982751e+01
#  -3.77086995e+01 -1.35803066e+02  6.98061435e+01 -6.73732167e+01
#  -2.41638144e+00]
# Epoch #1 of Classifier - 6 --> Cost J(W) is: 6139.942471114265
# Epoch #2 of Classifier - 6 --> Cost J(W) is: 2853.0147911398003
# Epoch #3 of Classifier - 6 --> Cost J(W) is: 5117.779747770736
# Epoch #4 of Classifier - 6 --> Cost J(W) is: 2503.8448915917147
# Epoch #5 of Classifier - 6 --> Cost J(W) is: 2849.606690975279
# Epoch #6 of Classifier - 6 --> Cost J(W) is: 2568.800424627198
# Epoch #7 of Classifier - 6 --> Cost J(W) is: 2509.287753001564
# Epoch #8 of Classifier - 6 --> Cost J(W) is: 2731.480826406074
# Epoch #9 of Classifier - 6 --> Cost J(W) is: 4911.545971021006
# Epoch #10 of Classifier - 6 --> Cost J(W) is: 2179.524695155213
# Epoch #11 of Classifier - 6 --> Cost J(W) is: 3219.3426762086506
# Epoch #12 of Classifier - 6 --> Cost J(W) is: 3679.8752194382123
# Epoch #13 of Classifier - 6 --> Cost J(W) is: 4333.937516371872
# Epoch #14 of Classifier - 6 --> Cost J(W) is: 3084.797965681471
# Epoch #15 of Classifier - 6 --> Cost J(W) is: 3339.112644645266
# Epoch #16 of Classifier - 6 --> Cost J(W) is: 12256.395950685375
# Epoch #17 of Classifier - 6 --> Cost J(W) is: 2918.1477114737595
# Epoch #18 of Classifier - 6 --> Cost J(W) is: 3755.5752768669786
# Epoch #19 of Classifier - 6 --> Cost J(W) is: 6554.977564811457
# Epoch #20 of Classifier - 6 --> Cost J(W) is: 3295.6150138815647
# Epoch #21 of Classifier - 6 --> Cost J(W) is: 3177.9260666125256
# Epoch #22 of Classifier - 6 --> Cost J(W) is: 7899.002386774573
# Epoch #23 of Classifier - 6 --> Cost J(W) is: 17029.44021231975
# Epoch #24 of Classifier - 6 --> Cost J(W) is: 2913.5047986778536
# Epoch #25 of Classifier - 6 --> Cost J(W) is: 6036.796102409768
# Epoch #26 of Classifier - 6 --> Cost J(W) is: 2888.2966444939234
# Epoch #27 of Classifier - 6 --> Cost J(W) is: 6868.929686154596
# Epoch #28 of Classifier - 6 --> Cost J(W) is: 2910.940061548575
# Epoch #29 of Classifier - 6 --> Cost J(W) is: 3249.137446541974
# Epoch #30 of Classifier - 6 --> Cost J(W) is: 2425.705059114773
# Epoch #31 of Classifier - 6 --> Cost J(W) is: 3170.663033900914
# Epoch #32 of Classifier - 6 --> Cost J(W) is: 2274.5855098823495
# Epoch #33 of Classifier - 6 --> Cost J(W) is: 5987.792737249283
# Epoch #34 of Classifier - 6 --> Cost J(W) is: 5861.068971644584
# Epoch #35 of Classifier - 6 --> Cost J(W) is: 4168.426751312123
# Epoch #36 of Classifier - 6 --> Cost J(W) is: 2451.8622929177222
# Epoch #37 of Classifier - 6 --> Cost J(W) is: 2707.3683975446615
# Epoch #38 of Classifier - 6 --> Cost J(W) is: 2300.3403001919182
# Epoch #39 of Classifier - 6 --> Cost J(W) is: 5379.25077229125
# Epoch #40 of Classifier - 6 --> Cost J(W) is: 2854.9283762396653
# Epoch #41 of Classifier - 6 --> Cost J(W) is: 3139.910327966642
# Epoch #42 of Classifier - 6 --> Cost J(W) is: 2229.1576902767997
# Epoch #43 of Classifier - 6 --> Cost J(W) is: 2639.6779095921534
# Epoch #44 of Classifier - 6 --> Cost J(W) is: 4477.703482718494
# Epoch #45 of Classifier - 6 --> Cost J(W) is: 2521.279192762768
# Epoch #46 of Classifier - 6 --> Cost J(W) is: 3962.5233649620054
# Epoch #47 of Classifier - 6 --> Cost J(W) is: 2280.27065258971
# Epoch #48 of Classifier - 6 --> Cost J(W) is: 2834.913852614635
# Epoch #49 of Classifier - 6 --> Cost J(W) is: 5012.944236126581
# Epoch #50 of Classifier - 6 --> Cost J(W) is: 3055.2087124645377
# Epoch #51 of Classifier - 6 --> Cost J(W) is: 2456.671055436223
# Epoch #52 of Classifier - 6 --> Cost J(W) is: 11934.704360219146
# Epoch #53 of Classifier - 6 --> Cost J(W) is: 3330.29135313849
# Epoch #54 of Classifier - 6 --> Cost J(W) is: 2212.315701139238
# Epoch #55 of Classifier - 6 --> Cost J(W) is: 4254.864174432752
# Epoch #56 of Classifier - 6 --> Cost J(W) is: 8313.651638779062
# Epoch #57 of Classifier - 6 --> Cost J(W) is: 2366.6112570779287
# Epoch #58 of Classifier - 6 --> Cost J(W) is: 2740.882327657272
# Epoch #59 of Classifier - 6 --> Cost J(W) is: 6602.328523438064
# Epoch #60 of Classifier - 6 --> Cost J(W) is: 2267.54463346012
# Epoch #61 of Classifier - 6 --> Cost J(W) is: 3341.9570334508844
# Epoch #62 of Classifier - 6 --> Cost J(W) is: 4362.128298394395
# Epoch #63 of Classifier - 6 --> Cost J(W) is: 2288.770472226898
# Epoch #64 of Classifier - 6 --> Cost J(W) is: 1881.294246809616
# Epoch #65 of Classifier - 6 --> Cost J(W) is: 3559.7774383496444
# Epoch #66 of Classifier - 6 --> Cost J(W) is: 3022.581626459581
# Epoch #67 of Classifier - 6 --> Cost J(W) is: 2584.853486428052
# Epoch #68 of Classifier - 6 --> Cost J(W) is: 2471.7801214502156
# Epoch #69 of Classifier - 6 --> Cost J(W) is: 2362.495237067917
# Epoch #70 of Classifier - 6 --> Cost J(W) is: 2045.5823935786968
# Epoch #71 of Classifier - 6 --> Cost J(W) is: 2249.56796148662
# Epoch #72 of Classifier - 6 --> Cost J(W) is: 4348.244477767705
# Epoch #73 of Classifier - 6 --> Cost J(W) is: 2421.491628195289
# Epoch #74 of Classifier - 6 --> Cost J(W) is: 2794.4598710288387
# Epoch #75 of Classifier - 6 --> Cost J(W) is: 3048.907137309313
# Epoch #76 of Classifier - 6 --> Cost J(W) is: 4390.006639244676
# Epoch #77 of Classifier - 6 --> Cost J(W) is: 2178.0249037862495
# Epoch #78 of Classifier - 6 --> Cost J(W) is: 3180.900504565248
# Epoch #79 of Classifier - 6 --> Cost J(W) is: 3679.523228163169
# Epoch #80 of Classifier - 6 --> Cost J(W) is: 3367.0685657134836
# Epoch #81 of Classifier - 6 --> Cost J(W) is: 2980.580500134047
# Epoch #82 of Classifier - 6 --> Cost J(W) is: 2400.992199354592
# Epoch #83 of Classifier - 6 --> Cost J(W) is: 7017.9117529985115
# Epoch #84 of Classifier - 6 --> Cost J(W) is: 4488.334008010478
# Epoch #85 of Classifier - 6 --> Cost J(W) is: 5719.8130921659
# Epoch #86 of Classifier - 6 --> Cost J(W) is: 7217.318177609556
# Epoch #87 of Classifier - 6 --> Cost J(W) is: 4034.789664023196
# Epoch #88 of Classifier - 6 --> Cost J(W) is: 2323.0223758659217
# Epoch #89 of Classifier - 6 --> Cost J(W) is: 3626.7611021015164
# Epoch #90 of Classifier - 6 --> Cost J(W) is: 2839.255972407365
# Epoch #91 of Classifier - 6 --> Cost J(W) is: 2175.8695448450962
# Epoch #92 of Classifier - 6 --> Cost J(W) is: 3116.2945874477605
# Epoch #93 of Classifier - 6 --> Cost J(W) is: 5190.655423051921
# Epoch #94 of Classifier - 6 --> Cost J(W) is: 1877.626137831789
# Epoch #95 of Classifier - 6 --> Cost J(W) is: 4565.195912157656
# Epoch #96 of Classifier - 6 --> Cost J(W) is: 2937.690904596397
# Epoch #97 of Classifier - 6 --> Cost J(W) is: 3593.884474821138
# Epoch #98 of Classifier - 6 --> Cost J(W) is: 2450.135908096317
# Epoch #99 of Classifier - 6 --> Cost J(W) is: 3292.660773734516
# Epoch #100 and Interation #12149of Classifier - 6 --> Cost J(W) is: 3194.313763066576
# Epoch #100 and Interation #12167of Classifier - 6 --> Cost J(W) is: 2096.7175658121573
# Epoch #100 of Classifier - 6 --> Cost J(W) is: 4140.7704148526045
# Optimum w_vector for the 6th classifier is: [ -28.           11.41642571 -178.60627839   12.35848822   -5.30115056
#   -38.39127514  -13.41254214  -16.5320376    27.09024263    2.19925982
#    -0.25913332  -24.94536739  -22.14203301  -89.80822046  -10.32420286
#   -57.78479538    1.336014  ]
# Epoch #1 of Classifier - 7 --> Cost J(W) is: 1197.7873404383902
# Epoch #2 of Classifier - 7 --> Cost J(W) is: 1661.4653094370574
# Epoch #3 of Classifier - 7 --> Cost J(W) is: 4691.351814297686
# Epoch #4 of Classifier - 7 --> Cost J(W) is: 11363.890933196677
# Epoch #5 of Classifier - 7 --> Cost J(W) is: 1707.5030680095367
# Epoch #6 of Classifier - 7 --> Cost J(W) is: 1901.2654328897509
# Epoch #7 of Classifier - 7 --> Cost J(W) is: 955.0298165546421
# Epoch #8 of Classifier - 7 --> Cost J(W) is: 1152.67882704853
# Epoch #9 of Classifier - 7 --> Cost J(W) is: 1285.7660168892849
# Epoch #10 of Classifier - 7 --> Cost J(W) is: 4260.125731655291
# Epoch #11 of Classifier - 7 --> Cost J(W) is: 1372.2647921792802
# Epoch #12 of Classifier - 7 --> Cost J(W) is: 1242.0977645223008
# Epoch #13 of Classifier - 7 --> Cost J(W) is: 1193.9478919854037
# Epoch #14 of Classifier - 7 --> Cost J(W) is: 1129.957357070945
# Epoch #15 of Classifier - 7 --> Cost J(W) is: 916.2387642035665
# Epoch #16 of Classifier - 7 --> Cost J(W) is: 1206.5431571823594
# Epoch #17 of Classifier - 7 --> Cost J(W) is: 1330.7003568883376
# Epoch #18 of Classifier - 7 --> Cost J(W) is: 1247.7303221694851
# Epoch #19 of Classifier - 7 --> Cost J(W) is: 1541.97540544444
# Epoch #20 of Classifier - 7 --> Cost J(W) is: 1307.1444669420475
# Epoch #21 of Classifier - 7 --> Cost J(W) is: 1299.9785823377033
# Epoch #22 of Classifier - 7 --> Cost J(W) is: 1675.9633327947329
# Epoch #23 of Classifier - 7 --> Cost J(W) is: 1143.3421539973774
# Epoch #24 of Classifier - 7 --> Cost J(W) is: 1220.4623499583058
# Epoch #25 of Classifier - 7 --> Cost J(W) is: 1019.0319794155631
# Epoch #26 of Classifier - 7 --> Cost J(W) is: 1832.2793826848542
# Epoch #27 of Classifier - 7 --> Cost J(W) is: 1198.7151837089857
# Epoch #28 of Classifier - 7 --> Cost J(W) is: 1236.356173932079
# Epoch #29 of Classifier - 7 --> Cost J(W) is: 1449.2849641553987
# Epoch #30 of Classifier - 7 --> Cost J(W) is: 1045.497832647204
# Epoch #31 of Classifier - 7 --> Cost J(W) is: 1257.7032011471372
# Epoch #32 of Classifier - 7 --> Cost J(W) is: 1325.3310942300304
# Epoch #33 of Classifier - 7 --> Cost J(W) is: 1223.3582689961124
# Epoch #34 of Classifier - 7 --> Cost J(W) is: 1506.9205697647426
# Epoch #35 of Classifier - 7 --> Cost J(W) is: 1463.8181876257486
# Epoch #36 of Classifier - 7 --> Cost J(W) is: 931.4022052019224
# Epoch #37 of Classifier - 7 --> Cost J(W) is: 1795.622736167783
# Epoch #38 of Classifier - 7 --> Cost J(W) is: 1466.5887648293817
# Epoch #39 of Classifier - 7 --> Cost J(W) is: 1253.82901008843
# Epoch #40 of Classifier - 7 --> Cost J(W) is: 1825.3711100601354
# Epoch #41 of Classifier - 7 --> Cost J(W) is: 1311.8086044382708
# Epoch #42 of Classifier - 7 --> Cost J(W) is: 1144.0705668655216
# Epoch #43 of Classifier - 7 --> Cost J(W) is: 1355.0367334599607
# Epoch #44 of Classifier - 7 --> Cost J(W) is: 1703.5484931305252
# Epoch #45 of Classifier - 7 --> Cost J(W) is: 1561.0895839087402
# Epoch #46 of Classifier - 7 --> Cost J(W) is: 1208.240462409552
# Epoch #47 of Classifier - 7 --> Cost J(W) is: 1479.4222493655025
# Epoch #48 of Classifier - 7 --> Cost J(W) is: 2998.9349218496086
# Epoch #49 of Classifier - 7 --> Cost J(W) is: 2097.596220886987
# Epoch #50 of Classifier - 7 --> Cost J(W) is: 1548.507458249252
# Epoch #51 of Classifier - 7 --> Cost J(W) is: 1047.233776341668
# Epoch #52 of Classifier - 7 --> Cost J(W) is: 1516.4709332020568
# Epoch #53 of Classifier - 7 --> Cost J(W) is: 1122.0554383252584
# Epoch #54 of Classifier - 7 --> Cost J(W) is: 1312.8639646048653
# Epoch #55 of Classifier - 7 --> Cost J(W) is: 1463.8840425718931
# Epoch #56 of Classifier - 7 --> Cost J(W) is: 2891.533619506672
# Epoch #57 of Classifier - 7 --> Cost J(W) is: 1103.967756376436
# Epoch #58 of Classifier - 7 --> Cost J(W) is: 1297.8783831124854
# Epoch #59 of Classifier - 7 --> Cost J(W) is: 5128.78750520511
# Epoch #60 of Classifier - 7 --> Cost J(W) is: 3380.0943860041366
# Epoch #61 of Classifier - 7 --> Cost J(W) is: 1074.7666348181458
# Epoch #62 of Classifier - 7 --> Cost J(W) is: 1206.393827175671
# Epoch #63 of Classifier - 7 --> Cost J(W) is: 1347.4748467723045
# Epoch #64 of Classifier - 7 --> Cost J(W) is: 1112.682759967382
# Epoch #65 of Classifier - 7 --> Cost J(W) is: 2497.846631062357
# Epoch #66 of Classifier - 7 --> Cost J(W) is: 1522.0999013444502
# Epoch #67 of Classifier - 7 --> Cost J(W) is: 4465.656072687441
# Epoch #68 of Classifier - 7 --> Cost J(W) is: 1996.2509232174414
# Epoch #69 of Classifier - 7 --> Cost J(W) is: 1328.3294671966416
# Epoch #70 of Classifier - 7 --> Cost J(W) is: 1316.7183252710822
# Epoch #71 of Classifier - 7 --> Cost J(W) is: 1189.3414451804308
# Epoch #72 of Classifier - 7 --> Cost J(W) is: 1003.8929264081445
# Epoch #73 of Classifier - 7 --> Cost J(W) is: 1970.3766998715753
# Epoch #74 of Classifier - 7 --> Cost J(W) is: 1000.0139918125898
# Epoch #75 of Classifier - 7 --> Cost J(W) is: 846.6563722967808
# Epoch #76 of Classifier - 7 --> Cost J(W) is: 1467.5928408734662
# Epoch #77 of Classifier - 7 --> Cost J(W) is: 2008.8293323310659
# Epoch #78 of Classifier - 7 --> Cost J(W) is: 1273.6899751244707
# Epoch #79 of Classifier - 7 --> Cost J(W) is: 2287.519841713949
# Epoch #80 of Classifier - 7 --> Cost J(W) is: 1293.5141828948274
# Epoch #81 of Classifier - 7 --> Cost J(W) is: 963.5533949680715
# Epoch #82 of Classifier - 7 --> Cost J(W) is: 1252.5922087336487
# Epoch #83 of Classifier - 7 --> Cost J(W) is: 1167.7762788837815
# Epoch #84 of Classifier - 7 --> Cost J(W) is: 3247.4527531105805
# Epoch #85 of Classifier - 7 --> Cost J(W) is: 2314.304301430636
# Epoch #86 of Classifier - 7 --> Cost J(W) is: 1163.8707520638181
# Epoch #87 of Classifier - 7 --> Cost J(W) is: 2167.5946980782337
# Epoch #88 of Classifier - 7 --> Cost J(W) is: 2497.2257837418083
# Epoch #89 of Classifier - 7 --> Cost J(W) is: 4248.973022276016
# Epoch #90 of Classifier - 7 --> Cost J(W) is: 2157.164504736013
# Epoch #91 of Classifier - 7 --> Cost J(W) is: 1371.2399507752837
# Epoch #92 of Classifier - 7 --> Cost J(W) is: 1207.913676398279
# Epoch #93 of Classifier - 7 --> Cost J(W) is: 1220.7531683088598
# Epoch #94 of Classifier - 7 --> Cost J(W) is: 1052.1452511962784
# Epoch #95 of Classifier - 7 --> Cost J(W) is: 1834.4120241837995
# Epoch #96 of Classifier - 7 --> Cost J(W) is: 1701.2348541441572
# Epoch #97 of Classifier - 7 --> Cost J(W) is: 1424.6899449804234
# Epoch #98 of Classifier - 7 --> Cost J(W) is: 1382.2968334186412
# Epoch #99 of Classifier - 7 --> Cost J(W) is: 1552.4117050507077
# Epoch #100 and Interation #12149of Classifier - 7 --> Cost J(W) is: 1219.5929731607014
# Epoch #100 of Classifier - 7 --> Cost J(W) is: 1219.5929731607014
# Optimum w_vector for the 7th classifier is: [-39.         -27.72550042  56.05110138 -27.04753445 -13.11412462
#  -52.12076814 -22.30436738 -14.96029299 -19.7990584   -2.89240071
#   -2.22118123   0.68825786  -7.69453079 -20.87030284 -73.68868615
#  -23.05399737  12.15916541]

# %%
ovr.plot_multiclass_histograms(X_aug = X_train_augmented, W = optimum_w_vector, 
                               y=T_train, fname = "Histogram Dry Bean Dataset", norm_W=False, 
                               scale=1, class_names=['SEKER','DERMASON','BOMBAY','HOROZ','CALI','SIRA','BARBUNYA'])
# Out:
# 8.40068577026696

# %%
optimum_w_vector.shape
# Out:
# (17, 7)

# %% [markdown]
# ## 2] (a) ii] Calculating Accuracy of Training Data of the Dry Bean Dataset.

# %%
print("Accuracy of the Training Set!")
for i in range(7):
    print("--------------------------------------------------------------------------------")
    print(f"Class {i} Vs Rest !")
    Y_hat_train = ovr.predict(optimum_w_vector=optimum_w_vector[:, i], X_train = X_train_augmented)
    T_train_changed = ovr.changeLabels(T_train, i)
    acc = ovr.calculateAccuracy(T=T_train_changed, Y_hat=Y_hat_train, n=n_train)
    print(f"Accuracy on the Training Set for Class {i} Vs. Rest is {acc}%")
    print("---------------------------------------------------------------------------------")
    print()
# Out:
# Accuracy of the Training Set!
# --------------------------------------------------------------------------------
# Class 0 Vs Rest !
# Accuracy on the Training Set for Class 0 Vs. Rest is 98.38354151359295%
# ---------------------------------------------------------------------------------
#
# --------------------------------------------------------------------------------
# Class 1 Vs Rest !
# Accuracy on the Training Set for Class 1 Vs. Rest is 95.24042779002367%
# ---------------------------------------------------------------------------------
#
# --------------------------------------------------------------------------------
# Class 2 Vs Rest !
# Accuracy on the Training Set for Class 2 Vs. Rest is 100.0%
# ---------------------------------------------------------------------------------
#
# --------------------------------------------------------------------------------
# Class 3 Vs Rest !
# Accuracy on the Training Set for Class 3 Vs. Rest is 98.45701689933873%
# ---------------------------------------------------------------------------------
#
# --------------------------------------------------------------------------------
# Class 4 Vs Rest !
# Accuracy on the Training Set for Class 4 Vs. Rest is 97.93452526736877%
# ---------------------------------------------------------------------------------
#
# --------------------------------------------------------------------------------
# Class 5 Vs Rest !
# Accuracy on the Training Set for Class 5 Vs. Rest is 93.34639562413258%
# ---------------------------------------------------------------------------------
#
# --------------------------------------------------------------------------------
# Class 6 Vs Rest !
# Accuracy on the Training Set for Class 6 Vs. Rest is 98.2365907421014%
# ---------------------------------------------------------------------------------

# %% [markdown]
# ## 2] (a) ii] Calculating the Tes Accuracy on the Test data of Dry Bean Dataset.

# %%
n_test, X_test, T_test = ovr.generateTestData(testData=test_data, printFlag=True) 
X_test_std = ovr.standardizeTestData(X_test=X_test)

X_test_augmented = ovr.augmentData(X=X_test_std, n=n_test)
print(f"Shape of Augmented X_test: {X_test_augmented.shape}")
# Out:
# ---------------------------------------------------
# TEST DATA OF BEAN DATASET:
#   Shape of Input Data: (1362, 17)
#   Number of Data Points: 1362
#   Number of Input Features: 16
#   Number of Target Classes: 7
# ---------------------------------------------------
# Shape of Augmented X_test: (1362, 17)

# %%
print("Accuracy of the Test Set!")
for i in range(7):
    print("--------------------------------------------------------------------------------")
    print(f"Class {i} Vs Rest !")
    Y_hat_test = ovr.predict(optimum_w_vector=optimum_w_vector[:, i], X_train = X_test_augmented)
    T_test_changed = ovr.changeLabels(T_test, i)
    acc = ovr.calculateAccuracy(T=T_test_changed, Y_hat=Y_hat_test, n=n_test)
    print(f"Accuracy on the Test Set for Class {i} Vs. Rest is {acc}%")
    print("---------------------------------------------------------------------------------")
    print()
# Out:
# Accuracy of the Test Set!
# --------------------------------------------------------------------------------
# Class 0 Vs Rest !
# Accuracy on the Test Set for Class 0 Vs. Rest is 98.60499265785609%
# ---------------------------------------------------------------------------------
#
# --------------------------------------------------------------------------------
# Class 1 Vs Rest !
# Accuracy on the Test Set for Class 1 Vs. Rest is 94.7136563876652%
# ---------------------------------------------------------------------------------
#
# --------------------------------------------------------------------------------
# Class 2 Vs Rest !
# Accuracy on the Test Set for Class 2 Vs. Rest is 99.92657856093979%
# ---------------------------------------------------------------------------------
#
# --------------------------------------------------------------------------------
# Class 3 Vs Rest !
# Accuracy on the Test Set for Class 3 Vs. Rest is 98.60499265785609%
# ---------------------------------------------------------------------------------
#
# --------------------------------------------------------------------------------
# Class 4 Vs Rest !
# Accuracy on the Test Set for Class 4 Vs. Rest is 97.79735682819384%
# ---------------------------------------------------------------------------------
#
# --------------------------------------------------------------------------------
# Class 5 Vs Rest !
# Accuracy on the Test Set for Class 5 Vs. Rest is 92.65785609397945%
# ---------------------------------------------------------------------------------
#
# --------------------------------------------------------------------------------
# Class 6 Vs Rest !
# Accuracy on the Test Set for Class 6 Vs. Rest is 98.16446402349486%
# ---------------------------------------------------------------------------------

# %% [markdown]
# ## 2] (b)-(d) Code and run each combining method. Tip: use the stored weight vectors from (a) to apply rules (i), (ii), (iii).For each method, report the following performance measures separately on the training Set

# %%
ovr.predictionTechnique1(X_train_augmented, T_train, optimum_w_vector, n_train)
# Out:
# (86.8887256102539, 5.167768797452854, 7.943505592293248)

# %%
ovr.predictionTechnique2(X_train_augmented, T_train, optimum_w_vector, n_train)
# Out:
# (91.59931422973304, 8.40068577026696, 0.0)

# %% [markdown]
# ## Using Prediction Method -> 1

# %%
classificationAccTrain_1, errorRateTrain_1, unclassifiedRateTrain_1 = ovr.predictionTechnique1(X_train_augmented, T_train, optimum_w_vector, n_train)
print("--------------------------------------------------------------------------------------------------------")
print(f"Classification Accuracy on Training Data: {classificationAccTrain_1}")
print(f"Error rate on Training Data: {errorRateTrain_1}")
print(f"Unclassified Rate on Training Data: {unclassifiedRateTrain_1}")
print("--------------------------------------------------------------------------------------------------------")

classificationAccTest_1, errorRateTest_1, unclassifiedRateTest_1 = ovr.predictionTechnique1(X_test_augmented, T_test, optimum_w_vector, n_test)
print("--------------------------------------------------------------------------------------------------------")
print(f"Classification Accuracy on Test Data: {classificationAccTest_1}")
print(f"Error rate on Test Data: {errorRateTest_1}")
print(f"Unclassified Rate on Test Data: {unclassifiedRateTest_1}")
print("--------------------------------------------------------------------------------------------------------")
# Out:
# --------------------------------------------------------------------------------------------------------
# Classification Accuracy on Training Data: 86.8887256102539
# Error rate on Training Data: 5.167768797452854
# Unclassified Rate on Training Data: 7.943505592293248
# --------------------------------------------------------------------------------------------------------
# --------------------------------------------------------------------------------------------------------
# Classification Accuracy on Test Data: 86.12334801762115
# Error rate on Test Data: 5.65345080763583
# Unclassified Rate on Test Data: 8.223201174743025
# --------------------------------------------------------------------------------------------------------

# %% [markdown]
# ## Using Prediction Method -> 2

# %%
classificationAccTrain_2, errorRateTrain_2, unclassifiedRateTrain_2 = ovr.predictionTechnique2(X_train_augmented, T_train, optimum_w_vector, n_train)
print("--------------------------------------------------------------------------------------------------------")
print(f"Classification Accuracy on Training Data: {classificationAccTrain_2}")
print(f"Error rate on Training Data: {errorRateTrain_2}")
print(f"Unclassified Rate on Training Data: {unclassifiedRateTrain_2}")
print("--------------------------------------------------------------------------------------------------------")

classificationAccTest_2, errorRateTest_2, unclassifiedRateTest_2 = ovr.predictionTechnique2(X_test_augmented, T_test, optimum_w_vector, n_test)
print("--------------------------------------------------------------------------------------------------------")
print(f"Classification Accuracy on Test Data: {classificationAccTest_2}")
print(f"Error rate on Test Data: {errorRateTest_2}")
print(f"Unclassified Rate on Test Data: {unclassifiedRateTest_2}")
print("--------------------------------------------------------------------------------------------------------")
# Out:
# --------------------------------------------------------------------------------------------------------
# Classification Accuracy on Training Data: 91.59931422973304
# Error rate on Training Data: 8.40068577026696
# Unclassified Rate on Training Data: 0.0
# --------------------------------------------------------------------------------------------------------
# --------------------------------------------------------------------------------------------------------
# Classification Accuracy on Test Data: 91.26284875183553
# Error rate on Test Data: 8.737151248164464
# Unclassified Rate on Test Data: 0.0
# --------------------------------------------------------------------------------------------------------

# %% [markdown]
# ## Using Prediction Method --> 3

# %%
classificationAccTrain_3, errorRateTrain_3, unclassifiedRateTrain_3 = ovr.predictionTechnique3(X_train_augmented, T_train, optimum_w_vector, n_train)
print("--------------------------------------------------------------------------------------------------------")
print(f"Classification Accuracy on Training Data: {classificationAccTrain_3}")
print(f"Error rate on Training Data: {errorRateTrain_3}")
print(f"Unclassified Rate on Training Data: {unclassifiedRateTrain_3}")
print("--------------------------------------------------------------------------------------------------------")

classificationAccTest_3, errorRateTest_3, unclassifiedRateTest_3 = ovr.predictionTechnique3(X_test_augmented, T_test, optimum_w_vector, n_test)
print("--------------------------------------------------------------------------------------------------------")
print(f"Classification Accuracy on Test Data: {classificationAccTest_3}")
print(f"Error rate on Test Data: {errorRateTest_3}")
print(f"Unclassified Rate on Test Data: {unclassifiedRateTest_3}")
print("--------------------------------------------------------------------------------------------------------")
# Out:
# --------------------------------------------------------------------------------------------------------
# Classification Accuracy on Training Data: 91.46869132174055
# Error rate on Training Data: 8.53130867825945
# Unclassified Rate on Training Data: 0.0
# --------------------------------------------------------------------------------------------------------
# --------------------------------------------------------------------------------------------------------
# Classification Accuracy on Test Data: 91.33627019089575
# Error rate on Test Data: 8.663729809104257
# Unclassified Rate on Test Data: 0.0
# --------------------------------------------------------------------------------------------------------

# %% [markdown]
# ## 2] (e) Compare the results of (b)-(d). Try to explain similarities and differences you observe.

# %% [markdown]
# ### We can clearly see that when we use the method-1 for prediction, the unclassified rate is <strong> 8.64% on Training Data </strong> and <strong> 8.45% on the Test Data </strong>. This is because when we use the One Vs Rest Decision rule, we might definitely get the indeterminate region which cannot be classified as a particular class. But its evident that the Accuracy is less compared to Method - 2 and Method - 3 but the Misclassification Rate is around 5 - 6 % on the Training and Test data. This is because when we cannot classsify a data point we just don't classify it rather than classifying it as some class.
#
# ### We can also notice that when we use the Method - 2 and Method - 3 for prediction, the unclassified rate is literally 0%. This is because we use the decision rule as argmax(g_x). Hence, even if its wrong, we get some class as output but we cannot be sure that its 100% correct. There is a boost in accuracy when compared to the Method - 1. But Misclasssification rate is around 8 - 9% which is higher than method - 1.
#
# ### The results of Method - 3 are almost similar to that of Method - 2 because here also we are using the argmax().
