# %% [markdown]
# # Homework : 1 Machine Learning - 1 (Supervised Methods)

# %% [markdown]
# ## a] Learning (training) and Classification using Unnormalized Data Points.

# %% [markdown]
# ### Importing Necessary Libraries

# %%
import pandas as pd

#Importing the nearestMeansClassifier library from utils package.
from utils import nearestMeansClassifier

# %% [markdown]
# ### Loading the Training Data and Testing Data from dataset-1 using Pandas

# %%
train_data_1 = pd.read_csv("./HW1_datasets/dataset1_train.csv", header=None)
print("Train Data -> 1: ")
print(train_data_1.head())
print()

test_data_1 = pd.read_csv("./HW1_datasets/dataset1_test.csv", header=None)
print("Test Data -> 1: ")
print(test_data_1.head())
# Out:
# Train Data -> 1:
#           0         1    2
# 0  2.199291  3.690399  1.0
# 1  0.472634 -0.709271  2.0
# 2 -0.026662 -1.335827  2.0
# 3 -0.116866 -1.336345  2.0
# 4  2.100909  1.143771  2.0
#
# Test Data -> 1:
#           0         1    2
# 0  1.226845  0.273791  2.0
# 1 -0.929775  0.300098  1.0
# 2  0.220924  0.835073  1.0
# 3  0.783772 -0.233020  2.0
# 4  2.116507  0.728805  2.0

# %% [markdown]
# ### Loading the Training Data and Testing Data from dataset-2 using Pandas

# %%
train_data_2 = pd.read_csv("./HW1_datasets/dataset2_train.csv", header=None)
print("Train Data -> 2: ")
print(train_data_2.head())
print()

test_data_2 = pd.read_csv("./HW1_datasets/dataset2_test.csv", header=None)
print("Train Data -> 2: ")
print(test_data_2.head())
print()
# Out:
# Train Data -> 2:
#           0         1    2
# 0  0.493655  0.905948  1.0
# 1  0.872053 -0.355721  2.0
# 2 -0.009021  0.132694  2.0
# 3 -0.578481  1.000596  1.0
# 4 -0.438395  1.038901  1.0
#
# Train Data -> 2:
#           0         1    2
# 0 -0.070044 -0.118457  2.0
# 1 -0.824375  0.892066  1.0
# 2  1.384810  0.016317  2.0
# 3  0.304828  0.286498  2.0
# 4  1.651588  0.902572  1.0

# %% [markdown]
# ### Loading the Training Data and Testing Data from dataset-3 using Pandas

# %%
train_data_3 = pd.read_csv("./HW1_datasets/dataset3_train.csv", header=None)
print("Train Data -> 3: ")
print(train_data_2.head())
print()

test_data_3 = pd.read_csv("./HW1_datasets/dataset3_test.csv", header=None)
print("Train Data -> 3: ")
print(test_data_2.head())
print()
# Out:
# Train Data -> 3:
#           0         1    2
# 0  0.493655  0.905948  1.0
# 1  0.872053 -0.355721  2.0
# 2 -0.009021  0.132694  2.0
# 3 -0.578481  1.000596  1.0
# 4 -0.438395  1.038901  1.0
#
# Train Data -> 3:
#           0         1    2
# 0 -0.070044 -0.118457  2.0
# 1 -0.824375  0.892066  1.0
# 2  1.384810  0.016317  2.0
# 3  0.304828  0.286498  2.0
# 4  1.651588  0.902572  1.0

# %%
nmc_train_1 = nearestMeansClassifier.NearestMeansClassifier(train_data_1)
nmc_test_1 = nearestMeansClassifier.NearestMeansClassifier(test_data_1)

# %%
nmc_train_1.generate_data()
nmc_train_1.findClassMeans()
nmc_train_1.plotBoundary()
nmc_train_1.classify()
print(f"Classification Error Rate (Accuracy) for Train Dataset - 1: {nmc_train_1.calculateAccuracy(True)}")
# Out:
# ---------------------------------------------------
#   Shape of Training Data: (100, 3)
#   Number of Data Points: 100
#   Number of Input Features: 2
#   Number of Target Classes: 2
# ---------------------------------------------------
#
# ----------#################################################################-------------
#
# ---------------------------------------------------
#   Shape of sample_means: (2, 2)
#   Sample Means:
# [[0.08893115 1.08956606]
#  [1.04128622 0.01994688]]
# ---------------------------------------------------
#
# ----------#################################################################-------------
# Classification Error Rate (Accuracy) for Train Dataset - 1: 100.0

# %%
nmc_test_1.generate_data()
nmc_test_1.findClassMeans()
nmc_test_1.plotBoundary()
nmc_test_1.classify()
print(f"Classification Error Rate (Accuracy) for Test Dataset - 1: {nmc_test_1.calculateAccuracy(True)}")
# Out:
# ---------------------------------------------------
#   Shape of Training Data: (100, 3)
#   Number of Data Points: 100
#   Number of Input Features: 2
#   Number of Target Classes: 2
# ---------------------------------------------------
#
# ----------#################################################################-------------
#
# ---------------------------------------------------
#   Shape of sample_means: (2, 2)
#   Sample Means:
# [[ 0.16711584  1.17607223]
#  [ 0.84177464 -0.17762815]]
# ---------------------------------------------------
#
# ----------#################################################################-------------
# Classification Error Rate (Accuracy) for Test Dataset - 1: 94.0

# %%
nmc_train_2 = nearestMeansClassifier.NearestMeansClassifier(train_data_2)
nmc_test_2 = nearestMeansClassifier.NearestMeansClassifier(test_data_2)

# %%
nmc_train_2.generate_data()
nmc_train_2.findClassMeans()
nmc_train_2.plotBoundary()
nmc_train_2.classify()
print(f"Classification Error Rate (Accuracy) for Train Dataset - 2: {nmc_train_2.calculateAccuracy(True)}")
# Out:
# ---------------------------------------------------
#   Shape of Training Data: (100, 3)
#   Number of Data Points: 100
#   Number of Input Features: 2
#   Number of Target Classes: 2
# ---------------------------------------------------
#
# ----------#################################################################-------------
#
# ---------------------------------------------------
#   Shape of sample_means: (2, 2)
#   Sample Means:
# [[-0.3536011   0.99036239]
#  [ 1.03652797 -0.03223129]]
# ---------------------------------------------------
#
# ----------#################################################################-------------
# Classification Error Rate (Accuracy) for Train Dataset - 2: 83.0

# %%
nmc_test_2.generate_data()
nmc_test_2.findClassMeans()
nmc_test_2.plotBoundary()
nmc_test_2.classify()
print(f"Classification Error Rate (Accuracy) for TestDataset - 2: {nmc_test_2.calculateAccuracy(True)}")
# Out:
# ---------------------------------------------------
#   Shape of Training Data: (100, 3)
#   Number of Data Points: 100
#   Number of Input Features: 2
#   Number of Target Classes: 2
# ---------------------------------------------------
#
# ----------#################################################################-------------
#
# ---------------------------------------------------
#   Shape of sample_means: (2, 2)
#   Sample Means:
# [[0.02187057 1.00796063]
#  [1.0171866  0.0292452 ]]
# ---------------------------------------------------
#
# ----------#################################################################-------------
# Classification Error Rate (Accuracy) for TestDataset - 2: 77.0

# %%
nmc_train_3 = nearestMeansClassifier.NearestMeansClassifier(train_data_3)
nmc_test_3 = nearestMeansClassifier.NearestMeansClassifier(test_data_3)

# %%
nmc_train_3.generate_data()
nmc_train_3.findClassMeans()
nmc_train_3.plotBoundary()
nmc_train_3.classify()
print(f"Classification Error Rate (Accuracy) for Train Dataset - 3: {nmc_train_3.calculateAccuracy(True)}")
# Out:
# ---------------------------------------------------
#   Shape of Training Data: (100, 3)
#   Number of Data Points: 100
#   Number of Input Features: 2
#   Number of Target Classes: 2
# ---------------------------------------------------
#
# ----------#################################################################-------------
#
# ---------------------------------------------------
#   Shape of sample_means: (2, 2)
#   Sample Means:
# [[-0.06738853  0.21324203]
#  [ 0.52230078  0.93267215]]
# ---------------------------------------------------
#
# ----------#################################################################-------------
# Classification Error Rate (Accuracy) for Train Dataset - 3: 77.0

# %%
nmc_test_3.generate_data()
nmc_test_3.findClassMeans()
nmc_test_3.plotBoundary()
nmc_test_3.classify()
print(f"Classification Error Rate (Accuracy) for Test Dataset - 3: {nmc_test_3.calculateAccuracy(True)}")
# Out:
# ---------------------------------------------------
#   Shape of Training Data: (100, 3)
#   Number of Data Points: 100
#   Number of Input Features: 2
#   Number of Target Classes: 2
# ---------------------------------------------------
#
# ----------#################################################################-------------
#
# ---------------------------------------------------
#   Shape of sample_means: (2, 2)
#   Sample Means:
# [[-0.12400501  0.59694378]
#  [ 0.47253934  1.00013444]]
# ---------------------------------------------------
#
# ----------#################################################################-------------
# Classification Error Rate (Accuracy) for Test Dataset - 3: 73.0
